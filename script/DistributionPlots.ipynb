# %%
import sys
import os
import pandas as pd
sys.path.insert(0, os.getcwd())

from DistributionPlots import DistributionPlots
DP = DistributionPlots()

# %%
data=pd.read_csv(r'C:\Users\ende\Desktop\SmartAd-Performance-Analysis-master\SmartAd-Performance-Analysis-master\data\final.csv')
data.head()
# Out:
#    Unnamed: 0                            auction_id experiment        date  \
# 0           2  0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05
# 1          16  008aafdf-deef-4482-8fec-d98e3da054da    exposed  2020-07-04
# 2          20  00a1384a-5118-4d1b-925b-6cdada50318d    exposed  2020-07-06
# 3          23  00b6fadb-10bd-49e3-a778-290da82f7a8d    control  2020-07-08
# 4          27  00ebf4a8-060f-4b99-93ac-c62724399483    control  2020-07-03
#
#    hour         device_make  platform_os                browser  yes  no
# 0     2               E5823            6  Chrome Mobile WebView    0   1
# 1    16  Generic Smartphone            6          Chrome Mobile    1   0
# 2     8  Generic Smartphone            6          Chrome Mobile    0   1
# 3     4    Samsung SM-A202F            6               Facebook    1   0
# 4    15  Generic Smartphone            6          Chrome Mobile    0   1

# %%
data[['yes','no','experiment']].value_counts()
# Out:
# yes  no  experiment
# 0    1   exposed       349
#          control       322
# 1    0   exposed       308
#          control       264
# dtype: int64

# %%
#new=data.groupby(['experiment']).count()
#new.columns
#new

# %%
#initializing variables based on data
#where C stands for Control, E stands for Exposed and cr stands for Conversation rate
C_aware = 264; C_total = 1243; C_cr = 0.21
E_aware = 308; E_total = 1243; E_cr = 0.24

# %%
#control group distribution with probability of getting the result from our exposed group
DP.cont_distribution(C_aware, C_total, C_cr, E_cr)

# %%
#comparison of control and exposed groups distribution against each other
DP.cont_exp_distribution(C_aware, E_aware, C_total, E_total, C_cr, E_cr)

# %%
#Null and alternative hypotheses plots with
#statistical power and significance levels defined and represented in the plots
DP.null_alt_distribution(C_total, E_total, C_cr, E_cr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2500/814778505.py in <module>
#       1 #Null and alternative hypotheses plots with
#       2 #statistical power and significance levels defined and represented in the plots
# ----> 3 DP.null_alt_distribution(C_total, E_total, C_cr, E_cr)
#
# c:\Users\ende\Desktop\SmartAd-Performance-Analysis-master\SmartAd-Performance-Analysis-master\script\DistributionPlots.py in null_alt_distribution(self, C_total, E_total, C_cr, E_cr)
#      42         bcr = C_cr
#      43         mde = E_cr - C_cr
# ---> 44         HPP.hypo_plot(C_total, E_total, bcr, mde, show_power=True, show_beta=True, show_alpha=True, show_p_value=True)
#
# c:\Users\ende\Desktop\SmartAd-Performance-Analysis-master\SmartAd-Performance-Analysis-master\script\HypothesisPlot.py in hypo_plot(self, Control, Exposed, bcr, mde, sig_level, show_power, show_beta, show_alpha, show_p_value, show_legend)
#      52                     'p-value = {0:.3f}'.format(p_value),
#      53                     fontsize=12, ha='left')
# ---> 54
#      55         # option to show legend
#      56         if show_legend:
#
# TypeError: show_area() got multiple values for argument 'area_type'
